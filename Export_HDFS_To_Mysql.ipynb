# %% [markdown]
# <a href="https://colab.research.google.com/github/Anilesh05/Anilesh05/blob/main/Export_HDFS_To_Mysql.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***Installing jdk and hadoop***

# %%
# !apt-get install openjdk-8-jdk
# !wget https://dlcdn.apache.org/hadoop/common/hadoop-2.10.2/hadoop-2.10.2.tar.gz
# !tar xf hadoop-2.10.2.tar.gz

import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["HADOOP_HOME"] = "/content/hadoop-2.10.2"
os.environ["HADOOP_COMMON_HOME"] = "/content/hadoop-2.10.2"
os.environ["HADOOP_MAPRED_HOME"] = "/content/hadoop-2.10.2"
os.environ["PATH"] = os.environ["HADOOP_HOME"] + "/bin:" + os.environ["PATH"]
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   fonts-dejavu-core fonts-dejavu-extra libatk-wrapper-java libatk-wrapper-java-jni libfontenc1
#   libgail-common libgail18 libgtk2.0-0 libgtk2.0-bin libgtk2.0-common libice-dev librsvg2-common
#   libsm-dev libxkbfile1 libxt-dev libxtst6 libxxf86dga1 openjdk-8-jdk-headless openjdk-8-jre
#   openjdk-8-jre-headless x11-utils
# Suggested packages:
#   gvfs libice-doc libsm-doc libxt-doc openjdk-8-demo openjdk-8-source visualvm libnss-mdns
#   fonts-nanum fonts-ipafont-gothic fonts-ipafont-mincho fonts-wqy-microhei fonts-wqy-zenhei
#   fonts-indic mesa-utils
# The following NEW packages will be installed:
#   fonts-dejavu-core fonts-dejavu-extra libatk-wrapper-java libatk-wrapper-java-jni libfontenc1
#   libgail-common libgail18 libgtk2.0-0 libgtk2.0-bin libgtk2.0-common libice-dev librsvg2-common
# ...

# %% [markdown]
# # ***Installing sqoop***

# %%
# !wget https://archive.apache.org/dist/sqoop/1.4.6/sqoop-1.4.6.bin__hadoop-2.0.4-alpha.tar.gz
# !tar -xvf sqoop-1.4.6.bin__hadoop-2.0.4-alpha.tar.gz

import os
os.environ["SQOOP_HOME"] = "/content/sqoop-1.4.6.bin__hadoop-2.0.4-alpha"
os.environ["PATH"] = os.environ["SQOOP_HOME"] + "/bin:" + os.environ["PATH"]

# !cp /content/sqoop-1.4.6.bin__hadoop-2.0.4-alpha/conf/sqoop-env-template.sh /content/sqoop-1.4.6.bin__hadoop-2.0.4-alpha/conf/sqoop-env.sh
# !echo "export HADOOP_COMMON_HOME=/content/hadoop-2.10.2" >> /content/sqoop-1.4.6.bin__hadoop-2.0.4-alpha/conf/sqoop-env.sh
# !echo "export HADOOP_MAPRED_HOME=/content/hadoop-2.10.2" >> /content/sqoop-1.4.6.bin__hadoop-2.0.4-alpha/sqoop-env.sh
# Out:
# --2024-04-02 05:29:56--  https://archive.apache.org/dist/sqoop/1.4.6/sqoop-1.4.6.bin__hadoop-2.0.4-alpha.tar.gz
# Resolving archive.apache.org (archive.apache.org)... 65.108.204.189, 2a01:4f9:1a:a084::2
# Connecting to archive.apache.org (archive.apache.org)|65.108.204.189|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 16870735 (16M) [application/x-gzip]
# Saving to: ‘sqoop-1.4.6.bin__hadoop-2.0.4-alpha.tar.gz’
#
# sqoop-1.4.6.bin__ha 100%[===================>]  16.09M  9.41MB/s    in 1.7s
#
# 2024-04-02 05:29:58 (9.41 MB/s) - ‘sqoop-1.4.6.bin__hadoop-2.0.4-alpha.tar.gz’ saved [16870735/16870735]
#
# sqoop-1.4.6.bin__hadoop-2.0.4-alpha/
# sqoop-1.4.6.bin__hadoop-2.0.4-alpha/bin/
# sqoop-1.4.6.bin__hadoop-2.0.4-alpha/conf/
# sqoop-1.4.6.bin__hadoop-2.0.4-alpha/docs/
# sqoop-1.4.6.bin__hadoop-2.0.4-alpha/docs/api/
# sqoop-1.4.6.bin__hadoop-2.0.4-alpha/docs/api/com/
# sqoop-1.4.6.bin__hadoop-2.0.4-alpha/docs/api/com/cloudera/
# ...

# %% [markdown]
# # ***Installing Mysql-Connector***

# %%
# !wget https://dev.mysql.com/get/Downloads/Connector-J/mysql-connector-j-8.3.0.tar.gz
# !tar xf mysql-connector-j-8.3.0.tar.gz
# !cp /content/mysql-connector-j-8.3.0/mysql-connector-j-8.3.0.jar /content/sqoop-1.4.6.bin__hadoop-2.0.4-alpha/lib
# Out:
# --2024-04-02 05:29:59--  https://dev.mysql.com/get/Downloads/Connector-J/mysql-connector-j-8.3.0.tar.gz
# Resolving dev.mysql.com (dev.mysql.com)... 23.79.31.75, 2600:1408:ec00:98e::2e31, 2600:1408:ec00:986::2e31
# Connecting to dev.mysql.com (dev.mysql.com)|23.79.31.75|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://cdn.mysql.com//Downloads/Connector-J/mysql-connector-j-8.3.0.tar.gz [following]
# --2024-04-02 05:29:59--  https://cdn.mysql.com//Downloads/Connector-J/mysql-connector-j-8.3.0.tar.gz
# Resolving cdn.mysql.com (cdn.mysql.com)... 104.110.136.48, 2600:1408:ec00:98d::1d68, 2600:1408:ec00:981::1d68
# Connecting to cdn.mysql.com (cdn.mysql.com)|104.110.136.48|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4255433 (4.1M) [application/x-tar-gz]
# Saving to: ‘mysql-connector-j-8.3.0.tar.gz’
#
# mysql-connector-j-8 100%[===================>]   4.06M  --.-KB/s    in 0.09s
#
# ...

# %% [markdown]
# # ***Installing Mysql Server***

# %%
# !apt-get -y install mysql-server
# !service mysql start
# !pip install mysql-connector-python
# !mysql -e "ALTER USER 'root'@'localhost' IDENTIFIED WITH 'mysql_native_password' BY 'root';FLUSH PRIVILEGES;"
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libcgi-fast-perl libcgi-pm-perl libclone-perl libencode-locale-perl libfcgi-bin libfcgi-perl
#   libfcgi0ldbl libhtml-parser-perl libhtml-tagset-perl libhtml-template-perl libhttp-date-perl
#   libhttp-message-perl libio-html-perl liblwp-mediatypes-perl libmecab2 libprotobuf-lite23
#   liburi-perl mecab-ipadic mecab-ipadic-utf8 mecab-utils mysql-client-8.0 mysql-client-core-8.0
#   mysql-server-8.0 mysql-server-core-8.0
# Suggested packages:
#   libdata-dump-perl libipc-sharedcache-perl libbusiness-isbn-perl libwww-perl mailx tinyca
# The following NEW packages will be installed:
#   libcgi-fast-perl libcgi-pm-perl libclone-perl libencode-locale-perl libfcgi-bin libfcgi-perl
#   libfcgi0ldbl libhtml-parser-perl libhtml-tagset-perl libhtml-template-perl libhttp-date-perl
# ...

# %% [markdown]
# ## ***Display All Packages Versions***

# %%
# !java -version
# !hadoop version
# !mysql --version
# !sqoop version
# Out:
# openjdk version "11.0.22" 2024-01-16
# OpenJDK Runtime Environment (build 11.0.22+7-post-Ubuntu-0ubuntu222.04.1)
# OpenJDK 64-Bit Server VM (build 11.0.22+7-post-Ubuntu-0ubuntu222.04.1, mixed mode, sharing)
# Hadoop 2.10.2
# Subversion Unknown -r 965fd380006fa78b2315668fbc7eb432e1d8200f
# Compiled by ubuntu on 2022-05-24T22:35Z
# Compiled with protoc 2.5.0
# From source with checksum d3ab737f7788f05d467784f0a86573fe
# This command was run using /content/hadoop-2.10.2/share/hadoop/common/hadoop-common-2.10.2.jar
# mysql  Ver 8.0.36-0ubuntu0.22.04.1 for Linux on x86_64 ((Ubuntu))
# ...
# Please set $HBASE_HOME to the root of your HBase installation.
# ...
# Please set $HCAT_HOME to the root of your HCatalog installation.
# ...
# Please set $ACCUMULO_HOME to the root of your Accumulo installation.
# ...
# Please set $ZOOKEEPER_HOME to the root of your Zookeeper installation.
# 24/04/02 05:30:52 INFO sqoop.Sqoop: Running Sqoop version: 1.4.6
# Sqoop 1.4.6
# ...

# %% [markdown]
# # ***Create a New Folder***

# %%
# !hdfs dfs -mkdir anilesh

# %% [markdown]
# # ***Create Mysql Database and Table Without Data***

# %%
import mysql.connector
from tabulate import tabulate

conn = mysql.connector.connect(user='root', password='root', host='localhost', port='3306')

cursor = conn.cursor()

cursor.execute("CREATE DATABASE IF NOT EXISTS Mysql_DB")

cursor.execute("USE Mysql_DB")

#cursor.execute("DROP TABLE EMPLOYEE")

create_table_query = '''CREATE TABLE EMPLOYEE (
   ID INT,
   FIRST_NAME CHAR(20) NOT NULL,
   LAST_NAME CHAR(20),
   DEPT CHAR(20),
   YEAR INT,
   EMAIL CHAR(50)
)'''
cursor.execute(create_table_query)

# Commit the changes
conn.commit()

# Execute the SELECT query
cursor.execute("SELECT * FROM EMPLOYEE")

# Fetch all the results
result = cursor.fetchall()

# Extract column names
columns = [desc[0] for desc in cursor.description]

# Display the data with aligned columns using tabulate
print(tabulate(result, headers=columns, tablefmt="grid"))


# Close the cursor and connection
cursor.close()
conn.close()
# Out:
# +------+--------------+-------------+--------+--------+---------+
# | ID   | FIRST_NAME   | LAST_NAME   | DEPT   | YEAR   | EMAIL   |
# +======+==============+=============+========+========+=========+
# +------+--------------+-------------+--------+--------+---------+

# %%
# %%writefile anil.txt
# 1,Anilesh,C,BCA(DS),2,anil@gmail.com
# 2,Anilesh,C,BCA(DS),2,anil@gmail.com
# 3,Anilesh,C,BCA(DS),2,anil@gmail.com
# Out:
# Writing anil.txt

# %%
# !cat /content/anil.txt
# Out:
# 1,Anilesh,C,BCA(DS),2,anil@gmail.com
# 2,Anilesh,C,BCA(DS),2,anil@gmail.com
# 3,Anilesh,C,BCA(DS),2,anil@gmail.com

# %%
# !hdfs dfs -mv /content/anil.txt  anilesh/export_table

# %%
# !hdfs dfs -cat anilesh/export_table/
# Out:
# 1,Anilesh,C,BCA(DS),2,anil@gmail.com
# 2,Anilesh,C,BCA(DS),2,anil@gmail.com
# 3,Anilesh,C,BCA(DS),2,anil@gmail.com

# %%
# !sqoop export \
  --connect jdbc:mysql://localhost:3306/Mysql_DB \
  --username root \
  --password root \
  --table EMPLOYEE \
  --export-dir anilesh/export_table \
  --m 1
# Out:
# ...
# Please set $HBASE_HOME to the root of your HBase installation.
# ...
# Please set $HCAT_HOME to the root of your HCatalog installation.
# ...
# Please set $ACCUMULO_HOME to the root of your Accumulo installation.
# ...
# Please set $ZOOKEEPER_HOME to the root of your Zookeeper installation.
# 24/04/02 05:31:00 INFO sqoop.Sqoop: Running Sqoop version: 1.4.6
# 24/04/02 05:31:00 WARN tool.BaseSqoopTool: Setting your password on the command-line is insecure. Consider using -P instead.
# 24/04/02 05:31:00 INFO manager.MySQLManager: Preparing to use a MySQL streaming resultset.
# 24/04/02 05:31:00 INFO tool.CodeGenTool: Beginning code generation
# Loading class `com.mysql.jdbc.Driver'. This is deprecated. The new driver class is `com.mysql.cj.jdbc.Driver'. The driver is automatically registered via the SPI and manual loading of the driver class is generally unnecessary.
# 24/04/02 05:31:02 INFO manager.SqlManager: Executing SQL statement: SELECT t.* FROM `EMPLOYEE` AS t LIMIT 1
# ...

# %% [markdown]
# # ***Display the Exported Table in Mysql***

# %%
conn = mysql.connector.connect(user='root', password='root', host='localhost', port='3306', database='Mysql_DB')

cursor = conn.cursor()

# Execute the SELECT query
cursor.execute("SELECT * FROM EMPLOYEE")

result = cursor.fetchall()

# Extract column names
columns = [desc[0] for desc in cursor.description]

# Display the data with aligned columns using tabulate
print(tabulate(result, headers=columns, tablefmt="grid"))
# Out:
# +------+--------------+-------------+---------+--------+----------------+
# |   ID | FIRST_NAME   | LAST_NAME   | DEPT    |   YEAR | EMAIL          |
# +======+==============+=============+=========+========+================+
# |    1 | Anilesh      | C           | BCA(DS) |      2 | anil@gmail.com |
# +------+--------------+-------------+---------+--------+----------------+
# |    2 | Anilesh      | C           | BCA(DS) |      2 | anil@gmail.com |
# +------+--------------+-------------+---------+--------+----------------+
# |    3 | Anilesh      | C           | BCA(DS) |      2 | anil@gmail.com |
# +------+--------------+-------------+---------+--------+----------------+
